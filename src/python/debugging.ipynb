# %%
import cv2
print("OpenCV version:", cv2.__version__)
print("cv2 file location:", cv2.__file__)
# Out:
# OpenCV version: 4.12.0
# cv2 file location: C:\Users\sures\AppData\Roaming\Python\Python312\site-packages\cv2\__init__.py

# %%
print("Has aruco module:", hasattr(cv2, "aruco"))
from cv2 import aruco
print("Has detectMarkers:", hasattr(aruco, "detectMarkers"))
print("A few sample functions:", [f for f in dir(aruco) if "Marker" in f])
# Out:
# Has aruco module: True
# Has detectMarkers: False
# A few sample functions: ['drawDetectedMarkers', 'generateImageMarker']
